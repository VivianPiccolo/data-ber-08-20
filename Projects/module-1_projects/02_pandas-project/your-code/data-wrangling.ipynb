# %%
import numpy as np
import pandas as pd
import random

# %%
shark = pd.read_csv('C:\\Users\\Vivi\\Documents\\Data\\MyLab\\data-ber-08-20\\Projects\\module-1_projects\\02_pandas-project\\GSAF5.csv', engine = "python" )

# %%
shark.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
shark_copy = shark.copy()

# %%
len(shark_copy.columns)
# Out:
# 24

# %%
shark_copy.size
# Out:
# 143808

# %%
len(shark_copy)
# Out:
# 5992

# %%
shark_copy.shape
# Out:
# (5992, 24)

# %%
dtype(shark_copy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-214-0d055b3ff37d> in <module>
# ----> 1 dtype(shark_copy)
#
# NameError: name 'dtype' is not defined

# %%
shark_copy.isna()
# Out:
#       Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0           False  False  False  False    False  False     False     False
# 1           False  False  False  False    False  False     False     False
# 2           False  False  False  False    False  False     False     False
# 3           False  False  False  False    False  False     False     False
# 4           False  False  False  False    False  False     False     False
# ...           ...    ...    ...    ...      ...    ...       ...       ...
# 5987        False  False  False  False    False  False     False     False
# 5988        False  False  False  False    False  False      True     False
# 5989        False  False  False  False    False  False     False     False
# 5990        False  False  False  False    False   True     False      True
# 5991        False  False  False  False    False  False     False     False
#
#        Name   Sex   ...  Species   Investigator or Source    pdf  \
# ...

# %%
shark_copy.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
missing_values =shark_copy.isna().sum()

# %%
#After checking the dataframe lenght, I know that the dataframe has 5992 rows.
#As columns Unnamed: 22 & Unnamed: 23 have 5991 and 5990 missing values each, I will remove those 2 columns.
#Years from column 'year' are already mentioned in the column 'date', therefore I will drop column 'Year'


newshark = shark_copy.drop(columns=["Unnamed: 22", "Unnamed: 23", "Year"])

# %%
newshark.head()
# Out:
#     Case Number       Date        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN  ...
# 4                       Bells Beach  Surfing             male    M  NaN  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# ...

# %%
newshark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Type                    5992 non-null   object
#  3   Country                 5949 non-null   object
#  4   Area                    5590 non-null   object
#  5   Location                5496 non-null   object
#  6   Activity                5465 non-null   object
#  7   Name                    5792 non-null   object
#  8   Sex                     5425 non-null   object
#  9   Age                     3311 non-null   object
#  10  Injury                  5965 non-null   object
#  11  Fatal (Y/N)             5973 non-null   object
#  12  Time                    2779 non-null   object
#  13  Species                 3058 non-null   object
# ...

# %%
missing_values_ratios = missing_values[missing_values.gt(0)]/len(shark)
missing_values_ratios

#even though missing info in the column time is high, I believe this info is quite important so I won't drop it.
# Out:
# Country                   0.007176
# Area                      0.067089
# Location                  0.082777
# Activity                  0.087951
# Name                      0.033378
# Sex                       0.094626
# Age                       0.447430
# Injury                    0.004506
# Fatal (Y/N)               0.003171
# Time                      0.536215
# Species                   0.489653
# Investigator or Source    0.002503
# href formula              0.000167
# href                      0.000501
# Unnamed: 22               0.999833
# Unnamed: 23               0.999666
# dtype: float64

# %%
#for 'Reported 06-Jul-1912' for example I wanted to delete the word reported
newshark['Date'] = newshark['Date'].str.replace('reported ', '')
newshark['Date']
# Out:
# 0         18-Sep-16
# 1         18-Sep-16
# 2         18-Sep-16
# 3         17-Sep-16
# 4         16-Sep-16
#            ...
# 5987    Before 1903
# 5988    Before 1903
# 5989      1900-1905
# 5990      1883-1889
# 5991      1845-1853
# Name: Date, Length: 5992, dtype: object

# %%
#for "No date, Before 1963" for example I don't see any real solution, but I will delete  'no date' as it is unusefull 
newshark['Date'] = newshark['Date'].str.replace('No date, ', '')
newshark['Date']
# Out:
# 0         18-Sep-16
# 1         18-Sep-16
# 2         18-Sep-16
# 3         17-Sep-16
# 4         16-Sep-16
#            ...
# 5987    Before 1903
# 5988    Before 1903
# 5989      1900-1905
# 5990      1883-1889
# 5991      1845-1853
# Name: Date, Length: 5992, dtype: object

# %%
#comparar se case name, case name 1 and case name 2 are the same

comparison_column = np.where(newshark2["Case Number.1"] == newshark2["Case Number.2"], True, False)
comparison_column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-224-84dc23f58bbe> in <module>
#       1 #comparar se case name, case name 1 and case name 2 are the same
#       2
# ----> 3 comparison_column = np.where(newshark2["Case Number.1"] == newshark2["Case Number.2"], True, False)
#       4 comparison_column
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
newshark = shark.drop(columns=["Case Number.2"])

# %%
#compare pdf and formula
comparison_column = np.where(newshark["href"] == newshark["href formula"], True, False)
comparison_column
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
newshark = shark.drop(columns=["href"])

# %%
newshark.columns=newshark.columns.str.lower().str.lstrip().str.rstrip().str.replace(' ','_')

# %%
#capitalize only the first letter of Country column values

newshark = newshark.Country.str.title()
print(newshark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-229-9a859417d73a> in <module>
#       1 #capitalize only the first letter of Country column values
#       2
# ----> 3 newshark = newshark.Country.str.title()
#       4 print(newshark)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
#capitalize only the first letter of Country column values => fix USA as now it's wrong

newshark['Country'] = newshark['Country'].str.replace('Usa', 'United States')
newshark['Country']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-230-91f10a959828> in <module>
# ...

# %%
#drop duplicate rows such as 'male/female' in column Name and not only column Sex
newshark.drop_duplicates(inplace=True)

# %%
#my codes are not working. I wanted to check the wrong values and then swap them to none
#print(set(newshark['sex']))
print(set(newshark.iloc['sex']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-f8c14890a053> in <module>
#       1 #my codes are not working. I wanted to check the wrong values and then swap them to none
#       2 #print(set(newshark['sex']))
# ----> 3 print(set(newshark.iloc['sex']))
#       4
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2133             key = item_from_zerodim(key)
#    2134             if not is_integer(key):
# -> 2135                 raise TypeError("Cannot index by location index with a non-integer key")
# ...

# %%
#my codes don't work. I wanted to check the wrong values and then swap them to none
#print(set(newshark['sex']))
print(set(newshark.iloc['activity']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-233-021eb00553c3> in <module>
#       1 #my codes don't work. I wanted to check the wrong values and then swap them to none
#       2 #print(set(newshark['sex']))
# ----> 3 print(set(newshark.iloc['activity']))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2133             key = item_from_zerodim(key)
#    2134             if not is_integer(key):
# -> 2135                 raise TypeError("Cannot index by location index with a non-integer key")
#    2136
# ...

# %%
newshark.describe
# Out:
# <bound method NDFrame.describe of        case_number         date  year        type             country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# ...

# %%
#Export
newshark.to_csv('GSAF5_cleaned.csv')
